# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
def load_data(file_path):
    data = pd.read_csv(file_path)
    return data

def convert_to_array(df, column):
    df[column] = df[column].apply(lambda x: np.fromstring(x.strip("[]"), sep=' '))

def split_columns(df, column):
    for i in range(3):
        df[f'{column}_{i+1}'] = df[column].apply(lambda x: x[i])

def process_data_head(df):
    for col in ['Head Position', 'Head Forward', 'Head Up']:
        convert_to_array(df, col)
        split_columns(df, col)
        df.drop(columns=[col], inplace=True)

def process_data_wrist(df):
    for col in ['Wrist position', 'Wrist orientation', 'Wrist radius']:
        convert_to_array(df, col)
        split_columns(df, col)
        df.drop(columns=[col], inplace=True)

# %%
head_data_Yang = load_data('Head_data/head_data_Yang.csv')
head_data_Gao = load_data('Head_data/head_data_Gao.csv')
head_data_Li = load_data('Head_data/Head_data_Li.csv')
head_data_u1 = load_data('Head_data/Head_data_u1_1.csv')
head_data_u2 = load_data('Head_data/Head_data_u2_1.csv')
head_data_u3 = load_data('Head_data/Head_data_u3_1.csv')
head_data_u4 = load_data('Head_data/Head_data_u4_1.csv')
head_data_u5 = load_data('Head_data/Head_data_u5_1.csv')
process_data_head(head_data_Yang)
process_data_head(head_data_Gao)
process_data_head(head_data_Li)
process_data_head(head_data_u1)
process_data_head(head_data_u2)
process_data_head(head_data_u3)
process_data_head(head_data_u4)
process_data_head(head_data_u5)
head_data_Yang['label'] = 0
head_data_Gao['label'] = 1
head_data_Li['label'] = 2
head_data_u1['label'] = 3
head_data_u2['label'] = 4
head_data_u3['label'] = 5
head_data_u4['label'] = 6
head_data_u5['label'] = 7
combined_data_head = pd.concat([head_data_Yang, head_data_Gao, head_data_Li, head_data_u1, head_data_u2, head_data_u3, head_data_u4, head_data_u5], ignore_index=True)

# %%
train_head, test_head = train_test_split(combined_data_head, test_size=0.2, random_state=42)

# %%
train_head.iloc[:, :-1] = train_head.iloc[:, :-1].astype('float32')
train_head.iloc[:, -1] = train_head.iloc[:, -1].astype(int)
test_head.iloc[:, :-1] = test_head.iloc[:, :-1].astype('float32')
test_head.iloc[:, -1] = test_head.iloc[:, -1].astype(int)
train_head.to_csv('data_head/train_head.csv', index=False, header=False)
test_head.to_csv('data_head/test_head.csv', index=False, header=False)

##upload data to s3
s3 = boto3.client('s3')
bucket_name = 'pretraindata'
s3.upload_file('data_head/train_head.csv', bucket_name, 'data_head/train_head.csv')
s3.upload_file('data_head/test_head.csv', bucket_name, 'data_head/test_head.csv')

# %%
import sagemaker
from sagemaker.amazon.amazon_estimator import RecordSet
from sagemaker.session import Session

# 获取角色
role = sagemaker.get_execution_role()

# 创建LinearLearner对象
multiclass_estimator = sagemaker.LinearLearner(
    role=role,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    predictor_type="multiclass_classifier",
    num_classes=8,  # 确保这个值与标签中的分类数一致
)

# 将数据包装在RecordSet对象中 
session = Session()

# 读取训练数据
s3_train_path = 's3://pretraindata/data_head/train_head.csv'
train_data = pd.read_csv(s3_train_path)
train_features = train_data.iloc[:, :-1].values.astype(np.float32)
train_labels = train_data.iloc[:, -1].values.astype(np.float32)
train_data_processed = pd.DataFrame(train_features)
train_data_processed['label'] = train_labels
print(train_data_processed.dtypes)
# Out:
# 0        float32
# 1        float32
# 2        float32
# 3        float32
# 4        float32
# 5        float32
# 6        float32
# 7        float32
# 8        float32
# label    float32
# dtype: object

# %%
# 创建RecordSet对象
train_records = multiclass_estimator.record_set(train_features, labels=train_labels, channel="train")

# 启动训练任务
multiclass_estimator.fit([train_records])
# Out:
# 2024-05-31 07:37:07 Starting - Starting the training job...
# 2024-05-31 07:37:22 Starting - Preparing the instances for training...
# 2024-05-31 07:37:47 Downloading - Downloading input data...
# 2024-05-31 07:38:16 Downloading - Downloading the training image......
# 2024-05-31 07:39:27 Training - Training image download completed. Training in progress...Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [05/31/2024 07:39:50 INFO 140266414565184] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [05/31/2024 07:39:50 INFO 140266414565184] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '9', 'mini_batch_size': '1000', 'num_classes': '8', 'predictor_type': 'multiclass_classifier'}
# [05/31/2024 07:39:50 INFO 140266414565184] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '9', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '8', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'multiclass_classifier'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [05/31/2024 07:39:53 WARNING 140266414565184] Loggers have already been setup.
# [05/31/2024 07:39:53 INFO 140266414565184] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '9', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '8', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'multiclass_classifier'}
# [05/31/2024 07:39:53 WARNING 140266414565184] Loggers have already been setup.
# Process 7 is a worker.
# [05/31/2024 07:39:53 INFO 140266414565184] Using default worker.
# [05/31/2024 07:39:53 INFO 140266414565184] Checkpoint loading and saving are disabled.
# [2024-05-31 07:39:53.668] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 13, "num_examples": 1, "num_bytes": 80000}
# [05/31/2024 07:39:53 INFO 140266414565184] Create Store: local
# [2024-05-31 07:39:53.712] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 43, "num_examples": 11, "num_bytes": 880000}
# [05/31/2024 07:39:53 INFO 140266414565184] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f91c1eb7b20>
# [05/31/2024 07:39:53 INFO 140266414565184] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [0.3952607  0.0467895  0.11020669 0.23347287 0.20689799 0.21518463
#  0.08478829 0.0344529  0.19944246]
# <NDArray 9 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [-0.30532092  0.04824888  0.006997   -0.12634383  0.12574463 -0.9080775
#   0.03625099  0.96747994  0.12047844]
# <NDArray 9 @cpu(0)>}
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [05/31/2024 07:39:53 INFO 140266414565184] nvidia-smi: took 0.032 seconds to run.
# [05/31/2024 07:39:53 INFO 140266414565184] nvidia-smi identified 0 GPUs.
# [05/31/2024 07:39:53 INFO 140266414565184] Number of GPUs being used: 0
# #metrics {"StartTime": 1717141193.7952685, "EndTime": 1717141193.7953057, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2024-05-31 07:39:54.636] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 840, "num_examples": 36, "num_bytes": 2845040}
# #metrics {"StartTime": 1717141194.6362805, "EndTime": 1717141194.6363447, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.004708748953683, "count": 1, "min": 1.004708748953683, "max": 1.004708748953683}}}
# #metrics {"StartTime": 1717141194.6364212, "EndTime": 1717141194.6364343, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9457436872209821, "count": 1, "min": 0.9457436872209821, "max": 0.9457436872209821}}}
# #metrics {"StartTime": 1717141194.6364655, "EndTime": 1717141194.6364741, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.085712051827567, "count": 1, "min": 1.085712051827567, "max": 1.085712051827567}}}
# #metrics {"StartTime": 1717141194.636501, "EndTime": 1717141194.636509, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7029258754185268, "count": 1, "min": 0.7029258754185268, "max": 0.7029258754185268}}}
# #metrics {"StartTime": 1717141194.6365378, "EndTime": 1717141194.6365464, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8908961521693638, "count": 1, "min": 0.8908961521693638, "max": 0.8908961521693638}}}
# #metrics {"StartTime": 1717141194.6365767, "EndTime": 1717141194.6365855, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9971496529715401, "count": 1, "min": 0.9971496529715401, "max": 0.9971496529715401}}}
# #metrics {"StartTime": 1717141194.6366117, "EndTime": 1717141194.6366189, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 11}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.47923039027622766, "count": 1, "min": 0.47923039027622766, "max": 0.47923039027622766}}}
# #metrics {"StartTime": 1717141197.4615202, "EndTime": 1717141197.4616394, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 12}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.48008467581612724, "count": 1, "min": 0.48008467581612724, "max": 0.48008467581612724}}}
# #metrics {"StartTime": 1717141197.461678, "EndTime": 1717141197.4616852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 13}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0217678379603794, "count": 1, "min": 1.0217678379603794, "max": 1.0217678379603794}}}
# [05/31/2024 07:39:57 INFO 140266414565184] #quality_metric: host=algo-1, epoch=3, train multiclass_cross_entropy_objective <loss>=0.3824985874720982
# [05/31/2024 07:39:57 INFO 140266414565184] #early_stopping_criteria_metric: host=algo-1, epoch=3, criteria=multiclass_cross_entropy_objective, value=0.14642750309535435
# [05/31/2024 07:39:57 INFO 140266414565184] Epoch 3: Loss improved. Updating best model
# [05/31/2024 07:39:57 INFO 140266414565184] Saving model for epoch: 3
# [05/31/2024 07:39:57 INFO 140266414565184] Saved checkpoint to "/tmp/tmpscjbtg7f/mx-mod-0000.params"
# [05/31/2024 07:39:57 INFO 140266414565184] #progress_metric: host=algo-1, completed 26.666666666666668 % of epochs
# #metrics {"StartTime": 1717141196.4398994, "EndTime": 1717141197.4705148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 154252.0, "count": 1, "min": 154252, "max": 154252}, "Total Batches Seen": {"sum": 156.0, "count": 1, "min": 156, "max": 156}, "Max Records Seen Between Resets": {"sum": 35563.0, "count": 1, "min": 35563, "max": 35563}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 35563.0, "count": 1, "min": 35563, "max": 35563}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [05/31/2024 07:39:57 INFO 140266414565184] #throughput_metric: host=algo-1, train throughput=34503.5687788133 records/second
# [2024-05-31 07:39:58.252] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 11, "duration": 781, "num_examples": 36, "num_bytes": 2845040}
# #metrics {"StartTime": 1717141198.2524338, "EndTime": 1717141198.2524855, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.37151634783063614, "count": 1, "min": 0.37151634783063614, "max": 0.37151634783063614}}}
# #metrics {"StartTime": 1717141198.2525494, "EndTime": 1717141198.2525597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.21730210963657925, "count": 1, "min": 0.21730210963657925, "max": 0.21730210963657925}}}
# #metrics {"StartTime": 1717141198.252594, "EndTime": 1717141198.252601, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0257929879324776, "count": 1, "min": 1.0257929879324776, "max": 1.0257929879324776}}}
# #metrics {"StartTime": 1717141198.2526236, "EndTime": 1717141198.2526324, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.37701031232561383, "count": 1, "min": 0.37701031232561383, "max": 0.37701031232561383}}}
# #metrics {"StartTime": 1717141198.252653, "EndTime": 1717141198.252661, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3010184378487723, "count": 1, "min": 0.3010184378487723, "max": 0.3010184378487723}}}
# #metrics {"StartTime": 1717141198.252686, "EndTime": 1717141198.2526946, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.2345244136265346, "count": 1, "min": 0.2345244136265346, "max": 0.2345244136265346}}}
# #metrics {"StartTime": 1717141198.2527235, "EndTime": 1717141198.2527294, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7036876395089285, "count": 1, "min": 0.7036876395089285, "max": 0.7036876395089285}}}
# #metrics {"StartTime": 1717141198.252747, "EndTime": 1717141198.2527518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3521214433942522, "count": 1, "min": 0.3521214433942522, "max": 0.3521214433942522}}}
# #metrics {"StartTime": 1717141198.2527683, "EndTime": 1717141198.2527733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 8}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.42899449288504465, "count": 1, "min": 0.42899449288504465, "max": 0.42899449288504465}}}
# #metrics {"StartTime": 1717141198.2527936, "EndTime": 1717141198.2528002, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 9}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.1449859412057059, "count": 1, "min": 0.1449859412057059, "max": 0.1449859412057059}}}
# #metrics {"StartTime": 1717141198.2528298, "EndTime": 1717141198.2528381, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 10}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.4923290579659598, "count": 1, "min": 0.4923290579659598, "max": 0.4923290579659598}}}
# #metrics {"StartTime": 1717141198.2529252, "EndTime": 1717141198.252938, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 11}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.479041748046875, "count": 1, "min": 0.479041748046875, "max": 0.479041748046875}}}
# #metrics {"StartTime": 1717141198.2529728, "EndTime": 1717141198.2529826, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 12}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.47821414010184154, "count": 1, "min": 0.47821414010184154, "max": 0.47821414010184154}}}
# #metrics {"StartTime": 1717141198.2530146, "EndTime": 1717141198.253024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 13}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0217342250279018, "count": 1, "min": 1.0217342250279018, "max": 1.0217342250279018}}}
# [05/31/2024 07:39:58 INFO 140266414565184] #quality_metric: host=algo-1, epoch=4, train multiclass_cross_entropy_objective <loss>=0.37151634783063614
# [05/31/2024 07:39:58 INFO 140266414565184] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=multiclass_cross_entropy_objective, value=0.1449859412057059
# [05/31/2024 07:39:58 INFO 140266414565184] Epoch 4: Loss improved. Updating best model
# [05/31/2024 07:39:58 INFO 140266414565184] Saving model for epoch: 4
# [05/31/2024 07:39:58 INFO 140266414565184] Saved checkpoint to "/tmp/tmpi0xjz5jh/mx-mod-0000.params"
# [05/31/2024 07:39:58 INFO 140266414565184] #progress_metric: host=algo-1, completed 33.333333333333336 % of epochs
# #metrics {"StartTime": 1717141197.4706945, "EndTime": 1717141198.2609956, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 189815.0, "count": 1, "min": 189815, "max": 189815}, "Total Batches Seen": {"sum": 192.0, "count": 1, "min": 192, "max": 192}, "Max Records Seen Between Resets": {"sum": 35563.0, "count": 1, "min": 35563, "max": 35563}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 35563.0, "count": 1, "min": 35563, "max": 35563}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [05/31/2024 07:39:58 INFO 140266414565184] #throughput_metric: host=algo-1, train throughput=44994.21536961659 records/second
# [2024-05-31 07:39:59.099] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 13, "duration": 837, "num_examples": 36, "num_bytes": 2845040}
# #metrics {"StartTime": 1717141199.0995424, "EndTime": 1717141199.099593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.36546864013671876, "count": 1, "min": 0.36546864013671876, "max": 0.36546864013671876}}}
# #metrics {"StartTime": 1717141199.099663, "EndTime": 1717141199.0996768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.2035829642159598, "count": 1, "min": 0.2035829642159598, "max": 0.2035829642159598}}}
# #metrics {"StartTime": 1717141199.0997076, "EndTime": 1717141199.0997171, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0260361537388394, "count": 1, "min": 1.0260361537388394, "max": 1.0260361537388394}}}
# #metrics {"StartTime": 1717141199.099745, "EndTime": 1717141199.0997524, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3770125723702567, "count": 1, "min": 0.3770125723702567, "max": 0.3770125723702567}}}
# #metrics {"StartTime": 1717141199.099781, "EndTime": 1717141199.0997896, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.2957273699079241, "count": 1, "min": 0.2957273699079241, "max": 0.2957273699079241}}}
# #metrics {"StartTime": 1717141199.0998256, "EndTime": 1717141199.0998352, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.2200489004952567, "count": 1, "min": 0.2200489004952567, "max": 0.2200489004952567}}}
# #metrics {"StartTime": 1717141199.0999064, "EndTime": 1717141199.0999198, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7036876412527902, "count": 1, "min": 0.7036876412527902, "max": 0.7036876412527902}}}
# #metrics {"StartTime": 1717141199.0999584, "EndTime": 1717141199.0999677, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.341255513218471, "count": 1, "min": 0.341255513218471, "max": 0.341255513218471}}}
# #metrics {"StartTime": 1717141199.0999978, "EndTime": 1717141199.1000068, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 8}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.4295045375279018, "count": 1, "min": 0.4295045375279018, "max": 0.4295045375279018}}}
# #metrics {"StartTime": 1717141199.1000383, "EndTime": 1717141199.1000483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 9}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.14509233594621931, "count": 1, "min": 0.14509233594621931, "max": 0.14509233594621931}}}
# #metrics {"StartTime": 1717141199.100079, "EndTime": 1717141199.1000884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 10}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.4858116428920201, "count": 1, "min": 0.4858116428920201, "max": 0.4858116428920201}}}
# #metrics {"StartTime": 1717141199.1001136, "EndTime": 1717141199.1001225, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 11}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.478781112234933, "count": 1, "min": 0.478781112234933, "max": 0.478781112234933}}}
# #metrics {"StartTime": 1717141199.1001556, "EndTime": 1717141199.1001651, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 12}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.4775245134626116, "count": 1, "min": 0.4775245134626116, "max": 0.4775245134626116}}}
# #metrics {"StartTime": 1717141199.100207, "EndTime": 1717141199.1002166, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "model": 13}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0217305140904018, "count": 1, "min": 1.0217305140904018, "max": 1.0217305140904018}}}
# [05/31/2024 07:39:59 INFO 140266414565184] #quality_metric: host=algo-1, epoch=5, train multiclass_cross_entropy_objective <loss>=0.36546864013671876
# [05/31/2024 07:39:59 INFO 140266414565184] #early_stopping_criteria_metric: host=algo-1, epoch=5, criteria=multiclass_cross_entropy_objective, value=0.14509233594621931
# [05/31/2024 07:39:59 INFO 140266414565184] Saving model for epoch: 5
# [05/31/2024 07:39:59 INFO 140266414565184] Saved checkpoint to "/tmp/tmpavq69xr7/mx-mod-0000.params"
# [05/31/2024 07:39:59 INFO 140266414565184] #progress_metric: host=algo-1, completed 40.0 % of epochs
# #metrics {"StartTime": 1717141198.2611618, "EndTime": 1717141199.1079233, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 5, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 225378.0, "count": 1, "min": 225378, "max": 225378}, "Total Batches Seen": {"sum": 228.0, "count": 1, "min": 228, "max": 228}, "Max Records Seen Between Resets": {"sum": 35563.0, "count": 1, "min": 35563, "max": 35563}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 35563.0, "count": 1, "min": 35563, "max": 35563}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [05/31/2024 07:39:59 INFO 140266414565184] #throughput_metric: host=algo-1, train throughput=41994.11120630072 records/second
# [2024-05-31 07:39:59.943] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 15, "duration": 835, "num_examples": 36, "num_bytes": 2845040}
# #metrics {"StartTime": 1717141199.943903, "EndTime": 1717141199.9439492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 6, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3619855712890625, "count": 1, "min": 0.3619855712890625, "max": 0.3619855712890625}}}
# #metrics {"StartTime": 1717141199.9440172, "EndTime": 1717141199.9440281, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 6, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.1944322017124721, "count": 1, "min": 0.1944322017124721, "max": 0.1944322017124721}}}
# ...
# #metrics {"StartTime": 1717141206.3040674, "EndTime": 1717141206.3040736, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.20708274623325892, "count": 1, "min": 0.20708274623325892, "max": 0.20708274623325892}}}
# #metrics {"StartTime": 1717141206.3041074, "EndTime": 1717141206.3041165, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7035700596400669, "count": 1, "min": 0.7035700596400669, "max": 0.7035700596400669}}}
# #metrics {"StartTime": 1717141206.3041441, "EndTime": 1717141206.3041527, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3221761945452009, "count": 1, "min": 0.3221761945452009, "max": 0.3221761945452009}}}
# #metrics {"StartTime": 1717141206.3041832, "EndTime": 1717141206.3041925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 8}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.4298678431919643, "count": 1, "min": 0.4298678431919643, "max": 0.4298678431919643}}}
# #metrics {"StartTime": 1717141206.3042343, "EndTime": 1717141206.3042438, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 9}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.14310148097446987, "count": 1, "min": 0.14310148097446987, "max": 0.14310148097446987}}}
# #metrics {"StartTime": 1717141206.3042736, "EndTime": 1717141206.3042834, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 10}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.47748050101143974, "count": 1, "min": 0.47748050101143974, "max": 0.47748050101143974}}}
# #metrics {"StartTime": 1717141206.3043134, "EndTime": 1717141206.3043222, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 11}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.47655735996791293, "count": 1, "min": 0.47655735996791293, "max": 0.47655735996791293}}}
# #metrics {"StartTime": 1717141206.304352, "EndTime": 1717141206.304361, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 12}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.47724000418526785, "count": 1, "min": 0.47724000418526785, "max": 0.47724000418526785}}}
# #metrics {"StartTime": 1717141206.304393, "EndTime": 1717141206.3044024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 13}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0215805245535714, "count": 1, "min": 1.0215805245535714, "max": 1.0215805245535714}}}
# [05/31/2024 07:40:06 INFO 140266414565184] #quality_metric: host=algo-1, epoch=13, train multiclass_cross_entropy_objective <loss>=0.35608499843052455
# [05/31/2024 07:40:06 INFO 140266414565184] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=multiclass_cross_entropy_objective, value=0.14310148097446987
# [05/31/2024 07:40:06 INFO 140266414565184] Saving model for epoch: 13
# [05/31/2024 07:40:06 INFO 140266414565184] Saved checkpoint to "/tmp/tmpt8stxx_4/mx-mod-0000.params"
# [05/31/2024 07:40:06 INFO 140266414565184] #progress_metric: host=algo-1, completed 93.33333333333333 % of epochs
# #metrics {"StartTime": 1717141205.51894, "EndTime": 1717141206.312134, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 509882.0, "count": 1, "min": 509882, "max": 509882}, "Total Batches Seen": {"sum": 516.0, "count": 1, "min": 516, "max": 516}, "Max Records Seen Between Resets": {"sum": 35563.0, "count": 1, "min": 35563, "max": 35563}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Number of Records Since Last Reset": {"sum": 35563.0, "count": 1, "min": 35563, "max": 35563}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [05/31/2024 07:40:06 INFO 140266414565184] #throughput_metric: host=algo-1, train throughput=44827.87908418456 records/second
# [2024-05-31 07:40:07.078] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 31, "duration": 766, "num_examples": 36, "num_bytes": 2845040}
# #metrics {"StartTime": 1717141207.0789602, "EndTime": 1717141207.0792062, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.35589805908203126, "count": 1, "min": 0.35589805908203126, "max": 0.35589805908203126}}}
# #metrics {"StartTime": 1717141207.07928, "EndTime": 1717141207.0792906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.1721177193777902, "count": 1, "min": 0.1721177193777902, "max": 0.1721177193777902}}}
# #metrics {"StartTime": 1717141207.0794456, "EndTime": 1717141207.0794559, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0264288609095982, "count": 1, "min": 1.0264288609095982, "max": 1.0264288609095982}}}
# #metrics {"StartTime": 1717141207.079484, "EndTime": 1717141207.0795066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3769415884835379, "count": 1, "min": 0.3769415884835379, "max": 0.3769415884835379}}}
# #metrics {"StartTime": 1717141207.0795326, "EndTime": 1717141207.0795398, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.28896163766043526, "count": 1, "min": 0.28896163766043526, "max": 0.28896163766043526}}}
# #metrics {"StartTime": 1717141207.0797307, "EndTime": 1717141207.0797408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.2070223358154297, "count": 1, "min": 0.2070223358154297, "max": 0.2070223358154297}}}
# #metrics {"StartTime": 1717141207.079767, "EndTime": 1717141207.0797737, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7035699532645089, "count": 1, "min": 0.7035699532645089, "max": 0.7035699532645089}}}
# #metrics {"StartTime": 1717141207.0797973, "EndTime": 1717141207.0798187, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.32180382167271204, "count": 1, "min": 0.32180382167271204, "max": 0.32180382167271204}}}
# #metrics {"StartTime": 1717141207.0798628, "EndTime": 1717141207.0798707, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.4297987016950335, "count": 1, "min": 0.4297987016950335, "max": 0.4297987016950335}}}
# #metrics {"StartTime": 1717141207.0798936, "EndTime": 1717141207.0798998, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.14242295466831753, "count": 1, "min": 0.14242295466831753, "max": 0.14242295466831753}}}
# #metrics {"StartTime": 1717141207.0799258, "EndTime": 1717141207.0799322, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.47741697649274556, "count": 1, "min": 0.47741697649274556, "max": 0.47741697649274556}}}
# #metrics {"StartTime": 1717141207.080005, "EndTime": 1717141207.0800133, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.476498579624721, "count": 1, "min": 0.476498579624721, "max": 0.476498579624721}}}
# #metrics {"StartTime": 1717141207.0800717, "EndTime": 1717141207.080079, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.4772547101702009, "count": 1, "min": 0.4772547101702009, "max": 0.4772547101702009}}}
# #metrics {"StartTime": 1717141207.080197, "EndTime": 1717141207.0802135, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.021583579799107, "count": 1, "min": 1.021583579799107, "max": 1.021583579799107}}}
# [05/31/2024 07:40:07 INFO 140266414565184] #quality_metric: host=algo-1, epoch=14, train multiclass_cross_entropy_objective <loss>=0.35589805908203126
# [05/31/2024 07:40:07 INFO 140266414565184] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=multiclass_cross_entropy_objective, value=0.14242295466831753
# [05/31/2024 07:40:07 INFO 140266414565184] Epoch 14: Loss improved. Updating best model
# [05/31/2024 07:40:07 INFO 140266414565184] Saving model for epoch: 14
# [05/31/2024 07:40:07 INFO 140266414565184] Saved checkpoint to "/tmp/tmpdaxrhq3l/mx-mod-0000.params"
# [05/31/2024 07:40:07 INFO 140266414565184] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1717141206.3124158, "EndTime": 1717141207.0882401, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 545445.0, "count": 1, "min": 545445, "max": 545445}, "Total Batches Seen": {"sum": 552.0, "count": 1, "min": 552, "max": 552}, "Max Records Seen Between Resets": {"sum": 35563.0, "count": 1, "min": 35563, "max": 35563}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 35563.0, "count": 1, "min": 35563, "max": 35563}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [05/31/2024 07:40:07 INFO 140266414565184] #throughput_metric: host=algo-1, train throughput=45832.49341589379 records/second
# [05/31/2024 07:40:07 WARNING 140266414565184] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/31/2024 07:40:07 WARNING 140266414565184] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2024-05-31 07:40:07.091] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 3, "num_examples": 1, "num_bytes": 80000}
# [2024-05-31 07:40:07.325] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 35, "duration": 230, "num_examples": 36, "num_bytes": 2845040}
# /opt/amazon/lib/python3.8/site-packages/numpy/core/fromnumeric.py:87: VisibleDeprecationWarning: Creating an ndarray from nested sequences exceeding the maximum number of dimensions of 32 is deprecated. If you mean to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# [05/31/2024 07:40:07 INFO 140266414565184] #train_score (algo-1) : ('multiclass_cross_entropy_objective', 0.1446066780949532)
# [05/31/2024 07:40:07 INFO 140266414565184] #train_score (algo-1) : ('multiclass_accuracy', 0.9664257796023957)
# [05/31/2024 07:40:07 INFO 140266414565184] #train_score (algo-1) : ('multiclass_top_k_accuracy_3', 0.9954447037651492)
# [05/31/2024 07:40:07 INFO 140266414565184] #train_score (algo-1) : ('dcg', 0.9855921504783325)
# [05/31/2024 07:40:07 INFO 140266414565184] #train_score (algo-1) : ('macro_recall', 0.93391746)
# [05/31/2024 07:40:07 INFO 140266414565184] #train_score (algo-1) : ('macro_precision', 0.97146887)
# [05/31/2024 07:40:07 INFO 140266414565184] #train_score (algo-1) : ('macro_f_1.000', 0.94837725)
# [05/31/2024 07:40:07 INFO 140266414565184] #train_score (algo-1) : ('multiclass_balanced_accuracy', 0.9339174407672386)
# [05/31/2024 07:40:07 INFO 140266414565184] #train_score (algo-1) : ('multiclass_log_loss', 1.351039178423662)
# [05/31/2024 07:40:07 INFO 140266414565184] #quality_metric: host=algo-1, train multiclass_cross_entropy_objective <loss>=0.1446066780949532
# [05/31/2024 07:40:07 INFO 140266414565184] #quality_metric: host=algo-1, train multiclass_accuracy <score>=0.9664257796023957
# [05/31/2024 07:40:07 INFO 140266414565184] #quality_metric: host=algo-1, train multiclass_top_k_accuracy_3 <score>=0.9954447037651492
# [05/31/2024 07:40:07 INFO 140266414565184] #quality_metric: host=algo-1, train dcg <score>=0.9855921504783325
# [05/31/2024 07:40:07 INFO 140266414565184] #quality_metric: host=algo-1, train macro_recall <score>=0.9339174628257751
# [05/31/2024 07:40:07 INFO 140266414565184] #quality_metric: host=algo-1, train macro_precision <score>=0.9714688658714294
# [05/31/2024 07:40:07 INFO 140266414565184] #quality_metric: host=algo-1, train macro_f_1.000 <score>=0.948377251625061
# [05/31/2024 07:40:07 INFO 140266414565184] #quality_metric: host=algo-1, train multiclass_balanced_accuracy <score>=0.9339174407672386
# [05/31/2024 07:40:07 INFO 140266414565184] #quality_metric: host=algo-1, train multiclass_log_loss <score>=1.351039178423662
# [05/31/2024 07:40:07 INFO 140266414565184] Best model found for hyperparameters: {"optimizer": "rmsprop", "learning_rate": 0.1375588030986051, "l1": 0.12007663993206846, "wd": 0.0011191600215386343, "lr_scheduler_step": 18, "lr_scheduler_factor": 0.9933274792584397, "lr_scheduler_minimum_lr": 0.00016511660035531799}
# [05/31/2024 07:40:07 INFO 140266414565184] Saved checkpoint to "/tmp/tmpf_v1jpn5/mx-mod-0000.params"
# [05/31/2024 07:40:07 INFO 140266414565184] Test data is not provided.
# #metrics {"StartTime": 1717141193.6548088, "EndTime": 1717141207.4207351, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 137.85529136657715, "count": 1, "min": 137.85529136657715, "max": 137.85529136657715}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 9.291648864746094, "count": 15, "min": 0.164031982421875, "max": 1.0821819305419922}, "update.time": {"sum": 13232.037782669067, "count": 15, "min": 772.7632522583008, "max": 1044.2230701446533}, "finalize.time": {"sum": 323.9712715148926, "count": 1, "min": 323.9712715148926, "max": 323.9712715148926}, "setuptime": {"sum": 1.9769668579101562, "count": 1, "min": 1.9769668579101562, "max": 1.9769668579101562}, "totaltime": {"sum": 13877.94828414917, "count": 1, "min": 13877.94828414917, "max": 13877.94828414917}}}
#
# 2024-05-31 07:40:26 Uploading - Uploading generated training model
# 2024-05-31 07:40:26 Completed - Training job completed
# Training seconds: 159
# Billable seconds: 159

# %%
# 部署模型
multiclass_predictor = multiclass_estimator.deploy(
    initial_instance_count=1,
    instance_type="ml.m4.xlarge"
)
# Out:
# -------!
